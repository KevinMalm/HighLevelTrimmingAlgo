# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from Sweep_Movement_Tracker import Sweep_Tracker

# %%
Tracker = Sweep_Tracker(circle = False)

# %%
print(' Working with a Rectangle Object')
Tracker.simulation_class.display_trimmed_img()
Tracker.RUN()
# Out:
#  Working with a Rectangle Object

# %%
Tracker.simulation_class.display_trimmed_img()
Tracker.plot_path()
plt.show()
# Out:
# TOTAL MOVES:  9481

# %%
print('Now Lets work with a Circle')
Tracker = Sweep_Tracker(circle = True)
Tracker.simulation_class.display_trimmed_img()
Tracker.RUN()
# Out:
# Now Lets work with a Circle

# %%
Tracker.simulation_class.display_trimmed_img()
Tracker.plot_path()
plt.show()
# Out:
# TOTAL MOVES:  4968
