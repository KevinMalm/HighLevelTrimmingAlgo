# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from N_Edge_PointTracker import N_EdgePointTracker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-67dfc21cf5a8> in <module>
# ----> 1 from N_Edge_PointTracker import N_EdgePointTracker
#
# ModuleNotFoundError: No module named 'N_Edge_PointTracker'

# %%
Tracker =  N_EdgePointTracker()

# %%
print('Original Setup Presented')
Tracker.simulation_class.display_trimmed_img()
# Out:
# Original Setup Presented

# %%
Tracker.FIND_EDGE_PTS()

# %%
print('Trimmed Result from Finding Edges')
Tracker.simulation_class.display_trimmed_img()
print('Display Edge Points and Current Trimmer Head Moves')
Tracker.plot_path()
# Out:
# Trimmed Result from Finding Edges
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e17f0d93fe71> in <module>
#       1 print('Trimmed Result from Finding Edges')
# ----> 2 Tracker.simulation_class.display_trimmed_img()
#       3 print('Display Edge Points and Current Trimmer Head Moves')
#       4 Tracker.plot_path()
#
# NameError: name 'Tracker' is not defined

# %%
Tracker.follow_circle_path()
Tracker.simulation_class.display_trimmed_img()
Tracker.plot_path()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-eacfeadd19cf> in <module>
# ----> 1 Tracker.follow_circle_path()
#       2 Tracker.simulation_class.display_trimmed_img()
#       3 Tracker.plot_path()
#       4 plt.show()
#
# NameError: name 'Tracker' is not defined
