# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from N_Edge_PointTracker import N_EdgePointTracker

# %%
Tracker =  N_EdgePointTracker()

# %%
print('Original Setup Presented')
Tracker.simulation_class.display_trimmed_img()
print('Colour Notes:')
print('Values of 2 (Typically Green) are Grass')
print('Values of 0 (Typically Blue) are where Grass is covering the Infastructure')
print('Values of -1 (Typically Purple) is the exposed surface of the Infrastructure')
# Out:
# Original Setup Presented
# Colour Notes:
# Values of 2 (Typically Green) are Grass
# Values of 0 (Typically Blue) are where Grass is covering the Infastructure
# Values of -1 (Typically Purple) is the exposed surface of the Infrastructure

# %%
Tracker.FIND_EDGE_PTS()

# %%
print('Trimmed Result from Finding Edges')
Tracker.simulation_class.display_trimmed_img()
print('Display Edge Points and Current Trimmer Head Moves')
Tracker.plot_path()
# Out:
# Trimmed Result from Finding Edges
# Display Edge Points and Current Trimmer Head Moves
# TOTAL MOVES:  1593

# %%
print('Smoothing Path  and Trimming Around Edge')
Tracker.follow_circle_path()
Tracker.simulation_class.display_trimmed_img()
print('Display Edge Points and Current Trimmer Head Moves')
Tracker.plot_path()
# Out:
# Smoothing Path  and Trimming Around Edge
# Display Edge Points and Current Trimmer Head Moves
# TOTAL MOVES:  1849
